# %%
#Made by Shivam Vatshayan & Cheenu Singh, Will complete till next week.

# %%
import pandas as pd

# %%
import numpy as np

# %%
Hospitalization_Discharge_rate=pd.read_csv("Discharge.csv")

# %%
Hospitalization_Discharge_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 15 columns):
# OBJECTID         26 non-null int64
# ZIP              26 non-null int64
# Anxiety_Di       26 non-null float64
# Mood_Disor       26 non-null float64
# Alcohol_re       26 non-null float64
# Diabetes         26 non-null float64
# Hypertensi       26 non-null float64
# Asthma           26 non-null float64
# F65_FallsER      26 non-null float64
# Discharges       26 non-null float64
# MH_ER            26 non-null float64
# Total_MH         26 non-null float64
# Total_ACSC       26 non-null int64
# Shape__Area      26 non-null float64
# Shape__Length    26 non-null float64
# dtypes: float64(12), int64(3)
# memory usage: 3.1 KB

# %%
Hospitalization_Discharge_rate.head()
# Out:
#    OBJECTID    ZIP  Anxiety_Di  Mood_Disor  Alcohol_re   Diabetes  Hypertensi  \
# 0         1  60002  393.608997  359.322499  270.177604  69.637883   20.481730
# 1         2  60010  132.835014  153.848463  177.863833  43.503045   19.501365
# 2         3  60015  142.476163  231.371546  147.347143  18.720048   16.224042
# 3         4  60020  201.704730  452.208992  406.662763  90.111739   66.081942
# 4         5  60030  261.648844  237.033796  250.708822  56.958420   37.972280
#
#       Asthma  F65_FallsER    Discharges       MH_ER     Total_MH  Total_ACSC  \
# 0  31.405320    14.946770   9590.103093  837.276281  1452.376054           0
# 1  16.501155     9.941825   8955.508619  388.936419   733.969741           0
# 2   6.240016    19.079395   8240.135205  496.383297   778.139042           0
# 3  60.074492    23.283437  13394.283515  911.331251  1506.278873           0
# 4  37.972280    20.297185  10486.759142  666.999426  1156.907256           0
#
#     Shape__Area  Shape__Length
# ...

# %%
Hospitalization_Discharge_rate.tail()
# Out:
#     OBJECTID    ZIP  Anxiety_Di  Mood_Disor  Alcohol_re    Diabetes  \
# 21        22  60085  509.524881  372.651592  494.056324  114.162202
# 22        23  60087  436.035489  284.370971  218.649680  110.467774
# 23        24  60089  169.135565  191.580095  183.564191   43.945006
# 24        25  60096  294.259527  241.196334  246.020260   38.514207
# 25        26  60099  461.371925  377.295036  233.313365  120.197658
#
#     Hypertensi      Asthma  F65_FallsER    Discharges        MH_ER  \
# 21   66.975158  101.477513    16.807367  12540.811584  1240.648554
# 22   57.138504   74.914927    19.223832  11480.190412   902.403883
# 23   20.403038   14.125180    19.720945   7512.066274   574.439688
# 24   25.676138   38.514207    10.297228   8301.671190   714.544139
# 25   77.905890  158.037662    22.575257  12642.674010  1075.133209
#
#        Total_MH  Total_ACSC   Shape__Area  Shape__Length
# 21  1839.352008           0  3.919074e+08  137038.947754
# ...

# %%
Hospitalization_Discharge_rate.head(100)
# Out:
#     OBJECTID    ZIP  Anxiety_Di  Mood_Disor  Alcohol_re    Diabetes  \
# 0          1  60002  393.608997  359.322499  270.177604   69.637883
# 1          2  60010  132.835014  153.848463  177.863833   43.503045
# 2          3  60015  142.476163  231.371546  147.347143   18.720048
# 3          4  60020  201.704730  452.208992  406.662763   90.111739
# 4          5  60030  261.648844  237.033796  250.708822   56.958420
# 5          6  60031  240.857947  234.704641  178.445851   60.977830
# 6          7  60035  129.593011  256.951660  245.779848   25.992225
# 7          8  60040  123.456790  308.641975  320.987654   18.072289
# 8          9  60042  261.025401  374.006545  214.274583   89.011167
# 9         10  60044  182.450343  230.644773  289.166581   35.961815
# 10        11  60045  173.848054  188.470787  264.833951   20.846697
# 11        12  60046  321.294357  357.631219  252.445566   77.380468
# 12        13  60047  187.110680  161.846790  179.215714   42.367358
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
fig=plt.figure()
ax = fig.add_subplot(1,1,1)
#Variable
ax.boxplot(df['ZIP'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-15a950008d2c> in <module>()
#       2 ax = fig.add_subplot(1,1,1)
#       3 #Variable
# ----> 4 ax.boxplot(df['ZIP'])
#       5 plt.show()
#
# NameError: name 'df' is not defined

# %%
import seaborn as sns 
sns.violinplot(df['Anxiety_Di'], df['Mood_Disor']) #Variable Plot
sns.despine()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-a363ef39bd63> in <module>()
#       1 import seaborn as sns
# ----> 2 sns.violinplot(df['Anxiety_Di'], df['Mood_Disor']) #Variable Plot
#       3 sns.despine()
#
# NameError: name 'df' is not defined

# %%
#Working !!
